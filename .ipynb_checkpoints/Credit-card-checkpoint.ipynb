# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
pd.options.display.max_colwidth = 200
pd.options.display.max_columns = 200
import numpy as np
from scipy.stats import norm
import time

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier,AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_predict,cross_val_score,train_test_split
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,auc,precision_recall_curve,roc_curve, log_loss
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA, TruncatedSVD
import warnings
warnings.filterwarnings('ignore')
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('creditcard.csv')

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9       V10       V11       V12  \
# ...

# %% [markdown]
# # EDA

# %%
df.Class.value_counts().plot(kind="bar")
print(df.Class.value_counts())
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df['Amount'] = StandardScaler().fit_transform(df[['Amount']])
features = pd.concat([df.loc[:,'V1':'Amount'],df.loc[:,'Time']],axis=1)
target = df['Class']

# %%
features
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10       V11       V12       V13  \
# ...

# %% [markdown]
# # Distribution of Amount

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,4))

amount_val = df['Amount'][df['Class']==1].values
amount_val_legit = df['Amount'][df['Class']==0].values

sns.distplot(amount_val, ax=ax[0], color='r')
ax[0].set_title('Distribution of Fraudulent Transaction Amount', fontsize=14)


sns.distplot(amount_val_legit, ax=ax[1], color='b')
ax[1].set_title('Distribution of Legit Transaction Amount', fontsize=14)

plt.show()

# %% [markdown]
# # Distribution of Time

# %%
fig, ax = plt.subplots(1, 2, figsize=(18,4))

time_val = df['Time'][df['Class']==1].values
time_val_legit = df['Time'][df['Class']==0].values

sns.distplot(time_val, ax=ax[0], color='r')
ax[0].set_title('Distribution of Fraudulent Transaction Time', fontsize=14)


sns.distplot(time_val_legit, ax=ax[1], color='b')
ax[1].set_title('Distribution of Legit Transaction Time', fontsize=14)

plt.show()

# %%
corrmat = df.corr() 
fig = plt.figure(figsize = (12, 9)) 
sns.heatmap(corrmat, vmax = .8, square = True) 
plt.show()

# %% [markdown]
# - Observation : We can clearly see that most of the features are not correlated with other features, but there are some features that are positively or negatively correlated with each other. For example, V2 and V5 are strongly negatively correlated with the Amount function.

# %%
fraud = df[df['Class']==1].sample(n =400,random_state=42)
legit = df[df['Class']==0].sample(n =400,random_state=42)

# %%
new_df = pd.concat([fraud,legit])
new_df.Class.value_counts().plot(kind="bar")
print(new_df.Class.value_counts())
# Out:
# 0    400
# 1    400
# Name: Class, dtype: int64

# %%
# %%time
# New_df is from the random undersample data (fewer instances)
X_vis = new_df.drop('Class', axis=1)
y_vis = new_df['Class']


# T-SNE Implementation
t0 = time.time()
X_reduced_tsne = TSNE(n_components=2, random_state=42).fit_transform(X_vis.values)
t1 = time.time()
print("T-SNE took {:.2} s".format(t1 - t0))

# PCA Implementation
t0 = time.time()
X_reduced_pca = PCA(n_components=2, random_state=42).fit_transform(X_vis.values)
t1 = time.time()
print("PCA took {:.2} s".format(t1 - t0))
# Out:
# T-SNE took 2.2 s
# PCA took 0.005 s
# Wall time: 2.18 s

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(24,6))
# labels = ['No Fraud', 'Fraud']
f.suptitle('Clusters using Dimensionality Reduction', fontsize=14)


blue_patch = mpatches.Patch(color='#0A0AFF', label='No Fraud')
red_patch = mpatches.Patch(color='#AF0000', label='Fraud')


# t-SNE scatter plot
ax1.scatter(X_reduced_tsne[:,0], X_reduced_tsne[:,1], c=(y_vis == 0), cmap='coolwarm', label='No Fraud', linewidths=2)
ax1.scatter(X_reduced_tsne[:,0], X_reduced_tsne[:,1], c=(y_vis == 1), cmap='coolwarm', label='Fraud', linewidths=2)
ax1.set_title('t-SNE', fontsize=14)

ax1.grid(True)

ax1.legend(handles=[blue_patch, red_patch])


# PCA scatter plot
ax2.scatter(X_reduced_pca[:,0], X_reduced_pca[:,1], c=(y_vis == 0), cmap='coolwarm', label='No Fraud', linewidths=2)
ax2.scatter(X_reduced_pca[:,0], X_reduced_pca[:,1], c=(y_vis == 1), cmap='coolwarm', label='Fraud', linewidths=2)
ax2.set_title('PCA', fontsize=14)

ax2.grid(True)

ax2.legend(handles=[blue_patch, red_patch])

# %%
ll = ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']

# %%
for i in ll:
    print(sns.distplot(df[i][df['Class']==1].values,fit=norm))
    plt.title(i)
    plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %% [markdown]
# # Models

# %%
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)

    
    A =(((C.T)/(C.sum(axis=1))).T)

    B =(C/C.sum(axis=0))

    
    labels = [1,2]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(5,3))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(5,3))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(5,3))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %% [markdown]
# # Building a random model (Finding worst-case log-loss)

# %%
x_train,x_test,y_train,y_test = train_test_split(features,target, stratify=target,test_size=0.35, random_state=1)

# %%
# ref: https://stackoverflow.com/a/18662466/4084039
# we create a output array that has exactly same size as the CV data
test_len = len(y_test)
predicted_y = np.zeros((test_len,2))
for i in range(test_len):
    rand_probs = np.random.rand(1,2)
    predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test, predicted_y, eps=1e-15))

predicted_y =np.argmax(predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y)
# Out:
# Log loss on Test Data using Random Model 0.8825302065671023
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # Logistic Regression with hyperparameter tuning

# %%
# %%time
from sklearn.linear_model import SGDClassifier
from sklearn.calibration import CalibratedClassifierCV
alpha = [10 ** x for x in range(-3, 1)]
log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(x_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(x_train, y_train)
    predict_y = sig_clf.predict_proba(x_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
# Out:
# For values of alpha =  0.001 The log loss is: 0.012702118908791946
# For values of alpha =  0.01 The log loss is: 0.012647569883897676
# For values of alpha =  0.1 The log loss is: 0.012593088279889223
# For values of alpha =  1 The log loss is: 0.012583657181694926
# Wall time: 2min 49s

# %% [markdown]
# # Fitting model with best alpha

# %%
best_alpha = np.argmin(log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l1', loss='log', random_state=42)
clf.fit(x_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(x_train, y_train)

predict_y = sig_clf.predict_proba(x_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(x_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :", len(predicted_y))
plot_confusion_matrix(y_test, predicted_y)
# Out:
# For values of best alpha =  1 The train log loss is: 0.012721791751878337
# For values of best alpha =  1 The test log loss is: 0.012702118908791946
# Total number of data points : 99683
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # with class balancing

# %%
# %%time
alpha = [10 ** x for x in range(-3, 1)]
log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l1', loss='log', random_state=42,class_weight='balanced')
    clf.fit(x_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(x_train, y_train)
    predict_y = sig_clf.predict_proba(x_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l1', loss='log', random_state=42,class_weight='balanced')
clf.fit(x_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(x_train, y_train)

predict_y = sig_clf.predict_proba(x_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(x_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :", len(predicted_y))
plot_confusion_matrix(y_test, predicted_y)
# Out:
# For values of alpha =  0.001 The log loss is: 0.012702118908791946
# For values of alpha =  0.01 The log loss is: 0.012702118908791946
# For values of alpha =  0.1 The log loss is: 0.004852141493524428
# For values of alpha =  1 The log loss is: 0.007997261734266913
# For values of best alpha =  0.1 The train log loss is: 0.005465357964779406
# For values of best alpha =  0.1 The test log loss is: 0.004852141493524428
# Total number of data points : 99683
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------
# Wall time: 4min 13s

# %% [markdown]
# # Hyperparameter tuning of xgboost

# %%
# %%time
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier

param_dist = {"n_estimators":[100,300,600],
              "max_depth": [2,6,8],
              "min_child_weight":[1,3]}
             

clf = XGBClassifier(random_state=25,n_jobs=-1)

xgb_random = RandomizedSearchCV(clf, param_distributions=param_dist,
                                   n_iter=3,cv=5,scoring='f1',random_state=25, verbose=3,n_jobs=-1)

xgb_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [17:58:04] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 7min 12s
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, gamma=None,
#                                            gpu_id=None, importance_type='gain',
#                                            interaction_constraints=None,
#                                            learning_rate=None,
# ...

# %%
print(xgb_random.best_estimator_)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=8,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=600, n_jobs=-1, num_parallel_tree=1, random_state=25,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# %%time
sig_clf = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
              importance_type='gain', interaction_constraints='',
              learning_rate=0.300000012, max_delta_step=0, max_depth=8,
              min_child_weight=1, monotone_constraints='()',
              n_estimators=600, n_jobs=-1, num_parallel_tree=1, random_state=25,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
              tree_method='exact', validate_parameters=1, verbosity=None)
sig_clf.fit(x_train,y_train)
# Out:
# [18:01:21] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Wall time: 47.1 s
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=8,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=600, n_jobs=-1, num_parallel_tree=1, random_state=25,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
predict_y = sig_clf.predict_proba(x_train)
print('train log loss is : ',log_loss(y_train,predict_y))
predict_y = sig_clf.predict_proba(x_test)
print('test log loss is :',log_loss(y_test,predict_y))
predicted_y = sig_clf.predict(x_test)
plot_confusion_matrix(y_test, predicted_y)
# Out:
# train log loss is :  1.774169047688294e-05
# test log loss is : 0.0027507287810979992
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
print('y_train class counts')
print(y_train.value_counts())
print('')
print('y_test class counts')
print(y_test.value_counts())


y_test_legit = y_test.value_counts()[0]
y_test_fraud = y_test.value_counts()[1]
# Out:
# y_train class counts
# 0    184804
# 1       320
# Name: Class, dtype: int64
#
# y_test class counts
# 0    99511
# 1      172
# Name: Class, dtype: int64

# %%
def PlotConfusionMatrix(y_test,pred,y_test_legit,y_test_fraud):

    cfn_matrix = confusion_matrix(y_test,pred)
    cfn_norm_matrix = np.array([[1.0 / y_test_legit,1.0/y_test_legit],[1.0/y_test_fraud,1.0/y_test_fraud]])
    norm_cfn_matrix = cfn_matrix * cfn_norm_matrix

    fig = plt.figure(figsize=(15,5))
    ax = fig.add_subplot(1,2,1)
    sns.heatmap(cfn_matrix,cmap='coolwarm_r',linewidths=0.5,annot=True,ax=ax)
    plt.title('Confusion Matrix')
    plt.ylabel('Real Classes')
    plt.xlabel('Predicted Classes')

    ax = fig.add_subplot(1,2,2)
    sns.heatmap(norm_cfn_matrix,cmap='coolwarm_r',linewidths=0.5,annot=True,ax=ax)

    plt.title('Normalized Confusion Matrix')
    plt.ylabel('Real Classes')
    plt.xlabel('Predicted Classes')
    plt.show()
    
    print('---Classification Report---')
    print(classification_report(y_test,pred))

PlotConfusionMatrix(y_test,pred,y_test_legit,y_test_fraud)
# Out:
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     99511
#            1       0.73      0.69      0.71       172
#
#     accuracy                           1.00     99683
#    macro avg       0.87      0.84      0.85     99683
# weighted avg       1.00      1.00      1.00     99683

# %%
lr_model = LogisticRegression(class_weight='balanced')
lr_model.fit(x_train,y_train)

pred = lr_model.predict(x_test)

PlotConfusionMatrix(y_test,pred,y_test_legit,y_test_fraud)
# Out:
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     99511
#            1       0.04      0.92      0.08       172
#
#     accuracy                           0.96     99683
#    macro avg       0.52      0.94      0.53     99683
# weighted avg       1.00      0.96      0.98     99683

# %% [markdown]
# # Manual Weights

# %%
for w in [1,5,10,100,500,1000]:
    print('---Weight of {} for Fraud class---'.format(w))
    lr_model = LogisticRegression(class_weight={0:1,1:w})
    lr_model.fit(x_train,y_train)

    pred = lr_model.predict(x_test)
    PlotConfusionMatrix(y_test,pred,y_test_legit,y_test_fraud)
# Out:
# ---Weight of 1 for Fraud class---
# C:\Users\snake\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     99511
#            1       0.73      0.69      0.71       172
#
#     accuracy                           1.00     99683
#    macro avg       0.87      0.84      0.85     99683
# weighted avg       1.00      1.00      1.00     99683
#
# ---Weight of 5 for Fraud class---
# ...

# %% [markdown]
# # Conclusion

# %% [markdown]
# - Logistic regression with manual weights has the best f1 score so we will save this model for deployment

# %%
lr_model = LogisticRegression(class_weight={0:1,1:1})
lr_model.fit(x_train,y_train)

pred = lr_model.predict(x_test)
PlotConfusionMatrix(y_test,pred,y_test_legit,y_test_fraud)
# Out:
# C:\Users\snake\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ---Classification Report---
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     99511
#            1       0.73      0.69      0.71       172
#
#     accuracy                           1.00     99683
#    macro avg       0.87      0.84      0.85     99683
# weighted avg       1.00      1.00      1.00     99683

# %% [markdown]
# # Saving model for flask api

# %%
lr_model.predict(np.array([x_test.loc[23308]]))
# Out:
# array([1], dtype=int64)

# %%
import pickle
# save the model to disk
filename = 'finalized_model.sav'
pickle.dump(lr_model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
loaded_model.predict(np.array([x_test.loc[23308]]))[0]
# Out:
# 1
